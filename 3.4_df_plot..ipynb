# %%
import pandas as pd

# %%
df=pd.read_excel("./남북한발전전력량.xlsx")

# %%
df.head()
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# 2  2658  2802  3196  3343  3430  3581  3427  3402  3523
# 3  1510  1478  1486  1547  1503  1388  1564  1648  1620
# 4     -     -     -     -    86   118   151   173   195
#
# [5 rows x 29 columns]

# %%
df.tail()
# Out:
#   전력량 (억㎾h) 발전 전력별 1990 1991 1992 1993 1994 1995 1996 1997  ... 2007 2008  \
# 4       NaN    신재생    -    -    -    -    -    -    -    -  ...    -    -
# 5        북한     합계  277  263  247  221  231  230  213  193  ...  236  255
# 6       NaN     수력  156  150  142  133  138  142  125  107  ...  133  141
# 7       NaN     화력  121  113  105   88   93   88   88   86  ...  103  114
# 8       NaN    원자력    -    -    -    -    -    -    -    -  ...    -    -
#
#   2009 2010 2011 2012 2013 2014 2015 2016
# 4    -    -    -   86  118  151  173  195
# 5  235  237  211  215  221  216  190  239
# 6  125  134  132  135  139  130  100  128
# 7  110  103   79   80   82   86   90  111
# 8    -    -    -    -    -    -    -    -
#
# [5 rows x 29 columns]

# %%
df.shape
# Out:
# (9, 29)

# %%
df
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
# 6       NaN     수력   156   150   142   133   138   142   125   107  ...   133
# 7       NaN     화력   121   113   105    88    93    88    88    86  ...   103
# 8       NaN    원자력     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# ...

# %%
df_ns=df.iloc[[0,5],3:]

# %%
df_ns
# Out:
#    1991  1992  1993  1994  1995  1996  1997  1998  1999  2000  ...  2007  \
# 0  1186  1310  1444  1650  1847  2055  2244  2153  2393  2664  ...  4031
# 5   263   247   221   231   230   213   193   170   186   194  ...   236
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 5   255   235   237   211   215   221   216   190   239
#
# [2 rows x 26 columns]

# %%
df_ns.index=["sorus","north"]

# %%
df_ns.columns=df_ns.columns.map(int)

# %%
df_ns.head()
# Out:
#        1991  1992  1993  1994  1995  1996  1997  1998  1999  2000  ...  2007  \
# sorus  1186  1310  1444  1650  1847  2055  2244  2153  2393  2664  ...  4031
# north   263   247   221   231   230   213   193   170   186   194  ...   236
#
#        2008  2009  2010  2011  2012  2013  2014  2015  2016
# sorus  4224  4336  4747  4969  5096  5171  5220  5281  5404
# north   255   235   237   211   215   221   216   190   239
#
# [2 rows x 26 columns]

# %%
df_ns.plot()
# Out:
# <AxesSubplot:>

# %%
tdf_ns=df_ns.T

# %%
tdf_ns #행과열을바꾸기
# Out:
#      sorus north
# 1991  1186   263
# 1992  1310   247
# 1993  1444   221
# 1994  1650   231
# 1995  1847   230
# 1996  2055   213
# 1997  2244   193
# 1998  2153   170
# 1999  2393   186
# 2000  2664   194
# 2001  2852   202
# 2002  3065   190
# 2003  3225   196
# 2004  3421   206
# 2005  3646   215
# 2006  3812   225
# 2007  4031   236
# 2008  4224   255
# 2009  4336   235
# 2010  4747   237
# 2011  4969   211
# 2012  5096   215
# 2013  5171   221
# 2014  5220   216
# 2015  5281   190
# 2016  5404   239

# %%
tdf_ns.plot()
# Out:
# <AxesSubplot:>

# %%
tdf_ns.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
tdf_ns['north'] = pd.to_numeric(tdf_ns['north'])
tdf_ns['sorus'] = pd.to_numeric(tdf_ns['sorus'])
tdf_ns.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
tdf_ns=tdf_ns.applyl(pd.to_numeric)
tdf_ns.plot(kind='hist')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 tdf_ns=tdf_ns.applyl(pd.to_numeric)
#       2 tdf_ns.plot(kind='hist')
#
# File ~\anaconda3\envs\pt3prer32\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'applyl'
